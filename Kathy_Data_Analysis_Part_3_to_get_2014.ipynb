# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
import os
import numpy
import requests as rq
import pandas as pd
from io import BytesIO
import json
from scipy import stats

# %%
csv_path = os.path.join('clean_data','labor_force_participation.csv')
with open(csv_path) as csvfile:
    labor_force_df = pd.read_csv(csv_path, header=[0])
    labor_force_df = pd.DataFrame(labor_force_df)
    labor_force_df = labor_force_df.set_index('Country Name')

# %%
labor_force_df
# Out:
#                       Labor Force Participation Female - 2018  \
# Country Name
# Brazil                                                  60.90
# Argentina                                               59.02
# Colombia                                                62.55
# United States                                           67.23
# United Kingdom                                          73.08
# United Arab Emirates                                    53.16
# Turkey                                                  38.15
# Norway                                                  75.27
# Greece                                                  60.17
# India                                                   22.16
# Singapore                                               69.39
# Vietnam                                                 79.71
# China                                                   68.78
# Nigeria                                                 49.11
# South Africa                                            53.85
# Egypt, Arab Rep.                                        20.02
# Australia                                               73.18
# Israel                                                  69.53
#
#                       Labor Force Participation Male - 2018
# Country Name
# Brazil                                                79.97
# Argentina                                             79.70
# Colombia                                              85.12
# United States                                         78.00
# United Kingdom                                        82.40
# United Arab Emirates                                  93.95
# Turkey                                                78.39
# Norway                                                80.13
# Greece                                                76.56
# India                                                 79.70
# Singapore                                             83.70
# Vietnam                                               86.69
# China                                                 82.85
# Nigeria                                               62.38
# South Africa                                          66.19
# Egypt, Arab Rep.                                      75.25
# Australia                                             82.95
# Israel                                                75.28

# %%
#find Differential between sexes and map to df
labor_force_df['Percent_Delta'] = labor_force_df['Labor Force Participation Male - 2018'] - labor_force_df['Labor Force Participation Female - 2018']
labor_force_df = labor_force_df.sort_values("Percent_Delta", ascending=False)
labor_force_df
# Out:
#                       Labor Force Participation Female - 2018  \
# Country Name
# India                                                   22.16
# Egypt, Arab Rep.                                        20.02
# United Arab Emirates                                    53.16
# Turkey                                                  38.15
# Colombia                                                62.55
# Argentina                                               59.02
# Brazil                                                  60.90
# Greece                                                  60.17
# Singapore                                               69.39
# China                                                   68.78
# Nigeria                                                 49.11
# South Africa                                            53.85
# United States                                           67.23
# Australia                                               73.18
# United Kingdom                                          73.08
# Vietnam                                                 79.71
# Israel                                                  69.53
# Norway                                                  75.27
#
#                       Labor Force Participation Male - 2018  Percent_Delta
# Country Name
# India                                                 79.70          57.54
# Egypt, Arab Rep.                                      75.25          55.23
# United Arab Emirates                                  93.95          40.79
# Turkey                                                78.39          40.24
# Colombia                                              85.12          22.57
# Argentina                                             79.70          20.68
# Brazil                                                79.97          19.07
# Greece                                                76.56          16.39
# Singapore                                             83.70          14.31
# China                                                 82.85          14.07
# Nigeria                                               62.38          13.27
# South Africa                                          66.19          12.34
# United States                                         78.00          10.77
# Australia                                             82.95           9.77
# United Kingdom                                        82.40           9.32
# Vietnam                                               86.69           6.98
# Israel                                                75.28           5.75
# Norway                                                80.13           4.86

# %%
# Filter the DataFrame down only to those columns to chart
labor_delta = labor_force_df[["Percent_Delta"]]
labor_delta.head()
# Out:
#                       Percent_Delta
# Country Name
# India                         57.54
# Egypt, Arab Rep.              55.23
# United Arab Emirates          40.79
# Turkey                        40.24
# Colombia                      22.57

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
labor_delta.plot(kind="bar", figsize=(7,5), color = 'green')

# Set a title for the chart
plt.title("Percentage Difference of Labor Force Participation between Males and Females")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
labor_force_mf = labor_force_df[["Labor Force Participation Male - 2018", "Labor Force Participation Female - 2018"]]
labor_force_mf.head()

labor_force_mf.plot(kind="bar", figsize=(7,5),color=['blue', 'red'])

# Set a title for the chart
plt.title("Who works more - Males or Females?")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# # World Bank Definition of Sectors:
#
# "High-level grouping of economic activities based on the on the types of goods and services produced." https://thedocs.worldbank.org/en/doc/538321490128452070-0290022017/original/NewSectorTaxonomyanddefinitions.pdf

# %%
csv_path = os.path.join('clean_data','employment_by_sector.csv')
with open(csv_path) as csvfile:
    emp_sector_df = pd.read_csv(csv_path, header=[0])
    emp_sector_df = pd.DataFrame(emp_sector_df)
    emp_sector_df = emp_sector_df.set_index('Country Name')

# %%
emp_sector_df
# Out:
#                       Agricultural Employment Female - 2018  \
# Country Name
# Brazil                                             4.140000
# Argentina                                          0.060000
# Colombia                                           7.810000
# United States                                      0.760000
# United Kingdom                                     0.620000
# United Arab Emirates                               0.010000
# Turkey                                            26.030001
# Norway                                             1.090000
# Greece                                            11.730000
# India                                             55.529999
# Singapore                                          0.020000
# Vietnam                                           39.900002
# China                                             22.780001
# Nigeria                                           24.240000
# South Africa                                       3.880000
# Egypt, Arab Rep.                                  21.690001
# Australia                                          1.680000
# Israel                                             0.490000
#
#                       Agricultural Employment Male - 2018  \
# Country Name
# Brazil                                          13.060000
# Argentina                                        0.120000
# Colombia                                        23.070000
# United States                                    1.890000
# United Kingdom                                   1.470000
# United Arab Emirates                             1.760000
# Turkey                                          14.860000
# Norway                                           3.010000
# Greece                                          12.640000
# India                                           40.240002
# Singapore                                        0.080000
# Vietnam                                         37.599998
# China                                           28.660000
# Nigeria                                         44.799999
# South Africa                                     6.170000
# Egypt, Arab Rep.                                21.660000
# Australia                                        3.440000
# Israel                                           1.390000
#
#                       Industry Employment Female - 2018  \
# Country Name
# Brazil                                        10.750000
# Argentina                                      9.140000
# Colombia                                      14.860000
# United States                                  8.780000
# United Kingdom                                 7.450000
# United Arab Emirates                           5.530000
# Turkey                                        16.070000
# Norway                                         7.000000
# Greece                                         7.730000
# India                                         17.280001
# Singapore                                     11.320000
# Vietnam                                       22.559999
# China                                         24.180000
# Nigeria                                       12.810000
# South Africa                                  11.620000
# Egypt, Arab Rep.                               8.250000
# Australia                                      8.150000
# Israel                                         8.080000
#
#                       Industry Employment Male - 2018  \
# Country Name
# Brazil                                      27.090000
# Argentina                                   31.309999
# Colombia                                    23.660000
# United States                               29.360001
# United Kingdom                              27.530001
# United Arab Emirates                        40.450001
# Turkey                                      31.639999
# Norway                                      30.570000
# Greece                                      20.480000
# India                                       26.889999
# Singapore                                   19.340000
# Vietnam                                     30.379999
# China                                       31.580000
# Nigeria                                     11.360000
# South Africa                                32.160000
# Egypt, Arab Rep.                            31.730000
# Australia                                   30.090000
# Israel                                      25.610001
#
#                       Service Employment Female - 2018  \
# Country Name
# Brazil                                       85.110001
# Argentina                                    90.809998
# Colombia                                     77.330002
# United States                                90.470001
# United Kingdom                               91.930000
# United Arab Emirates                         94.459999
# Turkey                                       57.900002
# Norway                                       91.910004
# Greece                                       80.550003
# India                                        27.190001
# Singapore                                    88.660004
# Vietnam                                      37.540001
# China                                        53.040001
# Nigeria                                      62.950001
# South Africa                                 84.510002
# Egypt, Arab Rep.                             70.070000
# Australia                                    90.180000
# Israel                                       91.440002
#
#                       Service Employment Male - 2018
# Country Name
# Brazil                                     59.840000
# Argentina                                  68.570000
# Colombia                                   53.279999
# United States                              68.750000
# United Kingdom                             71.000000
# United Arab Emirates                       57.790001
# Turkey                                     53.500000
# Norway                                     66.419998
# Greece                                     66.879997
# India                                      32.869999
# Singapore                                  80.580002
# Vietnam                                    32.020000
# China                                      39.759998
# Nigeria                                    43.840000
# South Africa                               61.669998
# Egypt, Arab Rep.                           46.619999
# Australia                                  66.480003
# Israel                                     73.000000

# %%
ag_sector_df = emp_sector_df.loc[:, ("Agricultural Employment Female - 2018", "Agricultural Employment Male - 2018")]
ag_sector_df['Percent_Delta'] = ag_sector_df['Agricultural Employment Male - 2018']- ag_sector_df['Agricultural Employment Female - 2018']
ag_sector_df = ag_sector_df.sort_values("Percent_Delta", ascending=False)
ag_sector_df
# Out:
#                       Agricultural Employment Female - 2018  \
# Country Name
# Nigeria                                           24.240000
# Colombia                                           7.810000
# Brazil                                             4.140000
# China                                             22.780001
# South Africa                                       3.880000
# Norway                                             1.090000
# Australia                                          1.680000
# United Arab Emirates                               0.010000
# United States                                      0.760000
# Greece                                            11.730000
# Israel                                             0.490000
# United Kingdom                                     0.620000
# Singapore                                          0.020000
# Argentina                                          0.060000
# Egypt, Arab Rep.                                  21.690001
# Vietnam                                           39.900002
# Turkey                                            26.030001
# India                                             55.529999
#
#                       Agricultural Employment Male - 2018  Percent_Delta
# Country Name
# Nigeria                                         44.799999      20.559999
# Colombia                                        23.070000      15.260000
# Brazil                                          13.060000       8.920001
# China                                           28.660000       5.879999
# South Africa                                     6.170000       2.290000
# Norway                                           3.010000       1.920000
# Australia                                        3.440000       1.760000
# United Arab Emirates                             1.760000       1.750000
# United States                                    1.890000       1.130000
# Greece                                          12.640000       0.910001
# Israel                                           1.390000       0.900000
# United Kingdom                                   1.470000       0.850000
# Singapore                                        0.080000       0.060000
# Argentina                                        0.120000       0.060000
# Egypt, Arab Rep.                                21.660000      -0.030001
# Vietnam                                         37.599998      -2.300003
# Turkey                                          14.860000     -11.170001
# India                                           40.240002     -15.289997

# %%
# Filter the DataFrame down only to those columns to chart
ag_delta = ag_sector_df[["Percent_Delta"]]
ag_delta.head()
# Out:
#               Percent_Delta
# Country Name
# Nigeria           20.559999
# Colombia          15.260000
# Brazil             8.920001
# China              5.879999
# South Africa       2.290000

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
ag_delta.plot(kind="bar", figsize=(5,3), color = 'green')

# Set a title for the chart
plt.title("Difference Labor Force Participation in Agriculture Sector between Males and Females")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
ag_sector_mf = emp_sector_df[["Agricultural Employment Female - 2018", "Agricultural Employment Male - 2018"]]

ag_sector_mf.plot(kind="bar", figsize=(10,5),color=['red', 'blue'])

# Set a title for the chart
plt.title("Who works more in Agriculture- Males or Females?")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
service_sector_df = emp_sector_df.loc[:, ("Service Employment Female - 2018", "Service Employment Male - 2018")]
service_sector_df['Percent_Delta'] = service_sector_df['Service Employment Male - 2018']- service_sector_df['Service Employment Female - 2018']
service_sector_df = service_sector_df.sort_values("Percent_Delta", ascending=False)
service_sector_df
# Out:
#                       Service Employment Female - 2018  \
# Country Name
# India                                        27.190001
# Turkey                                       57.900002
# Vietnam                                      37.540001
# Singapore                                    88.660004
# China                                        53.040001
# Greece                                       80.550003
# Israel                                       91.440002
# Nigeria                                      62.950001
# United Kingdom                               91.930000
# United States                                90.470001
# Argentina                                    90.809998
# South Africa                                 84.510002
# Egypt, Arab Rep.                             70.070000
# Australia                                    90.180000
# Colombia                                     77.330002
# Brazil                                       85.110001
# Norway                                       91.910004
# United Arab Emirates                         94.459999
#
#                       Service Employment Male - 2018  Percent_Delta
# Country Name
# India                                      32.869999       5.679998
# Turkey                                     53.500000      -4.400002
# Vietnam                                    32.020000      -5.520000
# Singapore                                  80.580002      -8.080002
# China                                      39.759998     -13.280003
# Greece                                     66.879997     -13.670006
# Israel                                     73.000000     -18.440002
# Nigeria                                    43.840000     -19.110001
# United Kingdom                             71.000000     -20.930000
# United States                              68.750000     -21.720001
# Argentina                                  68.570000     -22.239998
# South Africa                               61.669998     -22.840004
# Egypt, Arab Rep.                           46.619999     -23.450001
# Australia                                  66.480003     -23.699997
# Colombia                                   53.279999     -24.050003
# Brazil                                     59.840000     -25.270000
# Norway                                     66.419998     -25.490005
# United Arab Emirates                       57.790001     -36.669998

# %%
# Filter the DataFrame down only to those columns to chart
service_delta = service_sector_df[["Percent_Delta"]]
service_delta.head()
# Out:
#               Percent_Delta
# Country Name
# India              5.679998
# Turkey            -4.400002
# Vietnam           -5.520000
# Singapore         -8.080002
# China            -13.280003

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
#data['values'].plot(kind='barh',
                   # color=(data['values'] > 0).map({True: 'g',
                                                  #  False: 'r'}))
        
#service_delta['Percent_Delta'].plot(kind='barh', color=(service_delta['Percent_Delta']> 0).map({True:'b', False:'r'}))

service_delta.plot(kind="barh", figsize=(7,5), color = 'green')

# Set a title for the chart
plt.title("Difference Labor Force Participation in Service Sector between Males and Females")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
service_sector_mf = emp_sector_df[["Service Employment Female - 2018", "Service Employment Male - 2018"]]

service_sector_mf.plot(kind="bar", figsize=(7,5),color=['red', 'blue'])

# Set a title for the chart
plt.title("Who works more in Service- Males or Females?")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
industry_sector_df = emp_sector_df.loc[:, ("Industry Employment Female - 2018", "Industry Employment Male - 2018")]
industry_sector_df['Percent_Delta'] = industry_sector_df['Industry Employment Male - 2018']- industry_sector_df['Industry Employment Female - 2018']
industry_sector_df = industry_sector_df.sort_values("Percent_Delta", ascending=False)
industry_sector_df
# Out:
#                       Industry Employment Female - 2018  \
# Country Name
# United Arab Emirates                           5.530000
# Norway                                         7.000000
# Egypt, Arab Rep.                               8.250000
# Argentina                                      9.140000
# Australia                                      8.150000
# United States                                  8.780000
# South Africa                                  11.620000
# United Kingdom                                 7.450000
# Israel                                         8.080000
# Brazil                                        10.750000
# Turkey                                        16.070000
# Greece                                         7.730000
# India                                         17.280001
# Colombia                                      14.860000
# Singapore                                     11.320000
# Vietnam                                       22.559999
# China                                         24.180000
# Nigeria                                       12.810000
#
#                       Industry Employment Male - 2018  Percent_Delta
# Country Name
# United Arab Emirates                        40.450001      34.920001
# Norway                                      30.570000      23.570000
# Egypt, Arab Rep.                            31.730000      23.480000
# Argentina                                   31.309999      22.169999
# Australia                                   30.090000      21.940001
# United States                               29.360001      20.580001
# South Africa                                32.160000      20.540000
# United Kingdom                              27.530001      20.080001
# Israel                                      25.610001      17.530001
# Brazil                                      27.090000      16.340000
# Turkey                                      31.639999      15.570000
# Greece                                      20.480000      12.750000
# India                                       26.889999       9.609999
# Colombia                                    23.660000       8.800000
# Singapore                                   19.340000       8.020000
# Vietnam                                     30.379999       7.820000
# China                                       31.580000       7.400000
# Nigeria                                     11.360000      -1.450001

# %%
# Filter the DataFrame down only to those columns to chart
industry_delta = industry_sector_df[["Percent_Delta"]]
industry_delta.head()
# Out:
#                       Percent_Delta
# Country Name
# United Arab Emirates      34.920001
# Norway                    23.570000
# Egypt, Arab Rep.          23.480000
# Argentina                 22.169999
# Australia                 21.940001

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
industry_delta.plot(kind="bar", figsize=(7,5), color = 'green')

#def bar_color(industry_delta,color1,color2):
   # return np.where(industry_delta.values>0,color1,color2)

#industry_delta.plot.barh(color=bar_color(industry_delta,'red','blue'))

#def bar_color(df,color1,color2):
 #   return np.where(df.values>0,color1,color2)
# Set a title for the chart
plt.title("Difference Labor Force Participation in Industry Sector between Males and Females")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
industry_sector_mf = emp_sector_df[["Industry Employment Female - 2018", "Industry Employment Male - 2018"]]

industry_sector_mf.plot(kind="bar", figsize=(8,5),color=['red', 'blue'])

# Set a title for the chart
plt.title("Who works more in Industry- Males or Females?")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
csv_path = os.path.join('raw_data/WDI_Trimmed_Dataset_20220130.csv')
with open(csv_path) as csvfile:
    trimmed_df = pd.read_csv(csv_path, header=[0])
    trimmed_df = pd.DataFrame(trimmed_df)

# %%
# Isolate female labor force participation
labor_f_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.TLF.ACTI.FE.ZS']
labor_f_df = labor_f_df.set_index('Country Name')
labor_f_df = labor_f_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2018 [YR2018]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
labor_f_df = labor_f_df.rename(columns={"2014 [YR2014]": "Labor Force Participation Female - 2014"})
labor_f_df = labor_f_df.drop(index='Country List')

# Isolate male labor force participation
labor_m_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.TLF.ACTI.MA.ZS']
labor_m_df = labor_m_df.set_index('Country Name')
labor_m_df = labor_m_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2018 [YR2018]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
labor_m_df = labor_m_df.rename(columns={"2014 [YR2014]": "Labor Force Participation Male - 2014"})
labor_m_df = labor_m_df.drop(index='Country List')

labor_force_participation_2014_df = labor_f_df.merge(labor_m_df, on='Country Name')
print('Labor force participation rate for ages 15-64, female (%)')

labor_force_participation_2014_df.to_csv("clean_data/labor_force_participation_2014_test.csv", index=True, header=True)

labor_force_participation_2014_df
# Out:
# Labor force participation rate for ages 15-64, female (%)
#                      Labor Force Participation Female - 2014  \
# Country Name
# Brazil                                                 58.48
# Argentina                                              54.76
# Colombia                                               62.64
# United States                                             66
# United Kingdom                                         71.16
# United Arab Emirates                                   49.77
# Turkey                                                 33.45
# Norway                                                 75.78
# Greece                                                 59.22
# India                                                  23.46
# Singapore                                              67.32
# Vietnam                                                78.84
# China                                                  69.24
# Nigeria                                                49.68
# South Africa                                           51.11
# Egypt, Arab Rep.                                       25.59
# Australia                                              70.54
# Israel                                                 68.51
#
#                      Labor Force Participation Male - 2014
# Country Name
# Brazil                                               80.74
# Argentina                                            79.75
# Colombia                                             85.78
# United States                                        77.14
# United Kingdom                                       81.98
# United Arab Emirates                                 94.96
# Turkey                                               76.46
# Norway                                               79.88
# Greece                                               76.01
# India                                                81.48
# Singapore                                            83.08
# Vietnam                                              86.12
# China                                                83.09
# Nigeria                                              59.83
# South Africa                                         64.28
# Egypt, Arab Rep.                                     79.56
# Australia                                            82.12
# Israel                                               76.29

# %%
csv_path = os.path.join('clean_data','labor_force_participation_2014_test.csv')
with open(csv_path) as csvfile:
    labor_force_2014_df = pd.read_csv(csv_path, header=[0])
    labor_force_2014_df = pd.DataFrame(labor_force_2014_df)
    labor_force_2014_df = labor_force_2014_df.set_index('Country Name')

# %%
#find Differential between sexes and map to df
labor_force_2014_df['Percent_Delta'] = labor_force_2014_df['Labor Force Participation Male - 2014'] - labor_force_2014_df['Labor Force Participation Female - 2014']
labor_force_2014_df = labor_force_2014_df.sort_values("Percent_Delta", ascending=False)
labor_force_2014_df
# Out:
#                       Labor Force Participation Female - 2014  \
# Country Name
# India                                                   23.46
# Egypt, Arab Rep.                                        25.59
# United Arab Emirates                                    49.77
# Turkey                                                  33.45
# Argentina                                               54.76
# Colombia                                                62.64
# Brazil                                                  58.48
# Greece                                                  59.22
# Singapore                                               67.32
# China                                                   69.24
# South Africa                                            51.11
# Australia                                               70.54
# United States                                           66.00
# United Kingdom                                          71.16
# Nigeria                                                 49.68
# Israel                                                  68.51
# Vietnam                                                 78.84
# Norway                                                  75.78
#
#                       Labor Force Participation Male - 2014  Percent_Delta
# Country Name
# India                                                 81.48          58.02
# Egypt, Arab Rep.                                      79.56          53.97
# United Arab Emirates                                  94.96          45.19
# Turkey                                                76.46          43.01
# Argentina                                             79.75          24.99
# Colombia                                              85.78          23.14
# Brazil                                                80.74          22.26
# Greece                                                76.01          16.79
# Singapore                                             83.08          15.76
# China                                                 83.09          13.85
# South Africa                                          64.28          13.17
# Australia                                             82.12          11.58
# United States                                         77.14          11.14
# United Kingdom                                        81.98          10.82
# Nigeria                                               59.83          10.15
# Israel                                                76.29           7.78
# Vietnam                                               86.12           7.28
# Norway                                                79.88           4.10

# %%
labor_delta_2014= labor_force_2014_df[["Percent_Delta"]]
labor_delta_2014.head()
# Out:
#                       Percent_Delta
# Country Name
# India                         58.02
# Egypt, Arab Rep.              53.97
# United Arab Emirates          45.19
# Turkey                        43.01
# Argentina                     24.99

# %%
gdp_csv = 'clean_data/gdp_df.csv'
gdp_df = pd.read_csv(gdp_csv)
labor_delta_2014
gdp_v_labor_delta_2014 = pd.merge(gdp_df, labor_delta_2014, on='Country Name')
gdp_v_labor_delta_2014
gdp_v_labor_delta_2014.plot('2014 [YR2014]', 'Percent_Delta', kind='scatter')
x_values = gdp_v_labor_delta_2014['2014 [YR2014]']
y_values = gdp_v_labor_delta_2014['Percent_Delta']
# Perform a linear regression 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
rvalue,pvalue
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-0.28505146231025896, 0.25157383022958035)

# %%
gdp_v_labor_delta_2014.hist(column = 'Percent_Delta')
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<AxesSubplot:title={'center':'Percent_Delta'}>]], dtype=object)

# %%
gdp_v_labor_delta_2014.hist(column = '2014 [YR2014]')
# Out:
# array([[<AxesSubplot:title={'center':'2014 [YR2014]'}>]], dtype=object)

# %%
gdp_v_labor_delta_2014.boxplot(column = '2014 [YR2014]')
# Out:
# <AxesSubplot:>

# %%
gdp_v_labor_delta_2014.boxplot(column = 'Percent_Delta')
# Out:
# <AxesSubplot:>

# %%
gdp_df
# Out:
#             Country Name  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0                 Brazil       34236.71       33107.94       32876.20
# 1              Argentina       56999.67       57713.17       55759.61
# 2               Colombia       29073.65       29155.80       29448.86
# 3          United States      121656.12      123398.85      123455.29
# 4         United Kingdom       91699.07       92502.88       93210.80
# 5   United Arab Emirates       89203.53       93217.17       95720.18
# 6                 Turkey       74323.01       76263.49       76610.51
# 7                 Norway      121974.05      123637.32      125115.19
# 8                 Greece       86123.99       84378.14       82536.49
# 9                  India       14837.09       15882.34       17043.07
# 10             Singapore      148575.26      149188.97      152662.69
# 11               Vietnam       10298.18       10932.71       11558.29
# 12                 China       21584.39       23054.26       24577.83
# 13               Nigeria       18989.32       19133.18       19124.62
# 14          South Africa       48951.61       47801.66       48130.50
# 15      Egypt, Arab Rep.       35947.88       38039.23       38941.80
# 16             Australia       95581.51       95811.07       96879.17
# 17                Israel       85312.81       85112.41       86709.61
#
#     2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  2010-2020
# 0        33212.97       33207.95       32929.21       34683.65       0.46
# 1        56603.88       54249.57       52679.84       52706.35      -0.79
# 2        29407.35       29813.44       30874.89       32627.71       2.01
# 3       124337.14      126498.02      127582.92      130835.67       0.99
# 4        94133.24       94479.77       94956.26       86043.81      -0.40
# 5        97884.12       97683.54       99862.26       96628.59       2.23
# 6        79444.60       79690.92       81783.40       86076.46       2.92
# 7       127641.83      126887.48      126466.21      126410.51       0.58
# 8        81418.47       80668.85       79859.05       73326.64      -1.49
# 9        18059.02       19099.06       19574.93       19419.10       4.84
# 10      159727.94      164517.98      164282.44      161286.51       1.56
# 11       12215.53       12858.47       13817.35       14445.52       4.92
# 12       26242.67       28023.80       29859.59       31234.49       6.66
# 13       18690.86       18225.09       17846.67       17898.07       1.58
# 14       47726.05       47802.29       48108.68       48485.61      -0.10
# 15       40615.51       42372.56       43930.36       46966.01       3.17
# 16       97092.56       97591.35       97686.18       99553.64       1.10
# 17       88425.72       89993.40       91931.74       91224.98       1.23
