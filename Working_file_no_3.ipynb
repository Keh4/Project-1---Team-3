# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
import os
import numpy
import requests as rq
import pandas as pd
from io import BytesIO
import json

# %%
csv_path = os.path.join('raw_data/WDI_Trimmed_Dataset_20220130.csv')
with open(csv_path) as csvfile:
    trimmed_df = pd.read_csv(csv_path, header=[0])
    trimmed_df = pd.DataFrame(trimmed_df)

# %%
trimmed_df
# Out:
#           Country Name    Country Code  \
# 0               Brazil             BRA
# 1            Argentina             ARG
# 2             Colombia             COL
# 3        United States             USA
# 4       United Kingdom             GBR
# ...                ...             ...
# 1989      South Africa             ZAF
# 1990  Egypt, Arab Rep.             EGY
# 1991         Australia             AUS
# 1992            Israel             ISR
# 1993      Country List  (Country List)
#
#                                             Series Name        Series Code  \
# 0        Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 1        Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 2        Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 3        Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 4        Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# ...                                                 ...                ...
# 1989  Women Business and the Law Index Score (scale ...        SG.LAW.INDX
# 1990  Women Business and the Law Index Score (scale ...        SG.LAW.INDX
# 1991  Women Business and the Law Index Score (scale ...        SG.LAW.INDX
# 1992  Women Business and the Law Index Score (scale ...        SG.LAW.INDX
# 1993  Women Business and the Law Index Score (scale ...        SG.LAW.INDX
#
#      2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# 0     -0.142055812  -2.944151033  -3.120274597   0.891446292  -1.277958822
# 1     -3.446138435   5.050909519  -1.782622202   5.672500021  -6.949254354
# 2      5.514105365   4.136446767   2.458245854   1.159220033   1.839691684
# 3      3.484699201    3.62445752   0.902393835    2.10121282   2.500421858
# 4      4.148015229   2.997029907   1.708815694   2.475829083   1.125485088
# ...            ...           ...           ...           ...           ...
# 1989        88.125        88.125        88.125        88.125        88.125
# 1990         38.75            45            45            45            45
# 1991        96.875        96.875        96.875        96.875        96.875
# 1992        80.625        80.625        80.625        80.625        80.625
# 1993            ..            ..            ..            ..            ..
#
#      2019 [YR2019] 2020 [YR2020]    2010-2020
# 0      1.188818739            ..           ..
# 1     -4.698899588            ..           ..
# 2      2.926321559            ..           ..
# 3      2.384736913            ..           ..
# 4               ..            ..           ..
# ...            ...           ...          ...
# 1989        88.125        88.125  1.124779834
# 1990            45            45   1.49531734
# 1991        96.875        96.875   1.45585317
# 1992        80.625        80.625  0.395308388
# 1993            ..            ..           ..
#
# [1994 rows x 12 columns]

# %%
print("**************************")
print("GDP in Current US Dolloars")
print("**************************")

gdp_df = trimmed_df.loc[trimmed_df['Series Name'] == 'GDP (current US$)']
gdp_df = gdp_df.drop(columns='Series Code')
gdp_df = gdp_df.drop(columns='Country Code')
gdp_df = gdp_df.drop(columns='Series Name')
gdp_df = gdp_df.set_index('Country Name')
gdp_df = gdp_df.drop(index='Country List')
gdp_df
# Out:
# **************************
# GDP in Current US Dolloars
# **************************
#                      2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# Country Name
# Brazil                 2.45604E+12   1.80221E+12   1.79569E+12   2.06351E+12
# Argentina               5.2632E+11   5.94749E+11   5.57531E+11   6.43629E+11
# Colombia               3.81112E+11   2.93482E+11   2.82825E+11   3.11884E+11
# United States          1.75272E+13   1.82383E+13   1.87451E+13    1.9543E+13
# United Kingdom         3.08717E+12   2.95657E+12   2.72285E+12   2.69902E+12
# United Arab Emirates   4.03137E+11   3.58135E+11   3.57045E+11   3.85606E+11
# Turkey                 9.38953E+11   8.64317E+11   8.69693E+11   8.58996E+11
# Norway                  4.9841E+11   3.85802E+11   3.68827E+11   3.98394E+11
# Greece                 2.35145E+11   1.95605E+11   1.93017E+11   1.99351E+11
# India                  2.03913E+12   2.10359E+12    2.2948E+12   2.65147E+12
# Singapore              3.14851E+11   3.08004E+11   3.18764E+11   3.43338E+11
# Vietnam                1.86205E+11   1.93241E+11   2.05276E+11    2.2378E+11
# China                  1.04757E+13   1.10616E+13   1.12333E+13   1.23104E+13
# Nigeria                5.46676E+11   4.86803E+11    4.0465E+11   3.75746E+11
# South Africa           3.81199E+11    3.4671E+11   3.23586E+11   3.81449E+11
# Egypt, Arab Rep.       3.05595E+11   3.29367E+11   3.32442E+11   2.35734E+11
# Australia               1.4675E+12   1.35053E+12   1.20669E+12   1.32688E+12
# Israel                 3.10945E+11   3.00078E+11   3.19024E+11   3.55277E+11
#
#                      2018 [YR2018] 2019 [YR2019] 2020 [YR2020]     2010-2020
# Country Name
# Brazil                 1.91693E+12   1.87782E+12   1.44473E+12  -4.245419259
# Argentina               5.2482E+11   4.51932E+11   3.89288E+11  -0.845347733
# Colombia               3.34198E+11    3.2343E+11   2.71438E+11  -0.542265093
# United States          2.06119E+13   2.14332E+13   2.08937E+13   3.319296372
# United Kingdom         2.90079E+12   2.87867E+12    2.7642E+12   1.040219817
# United Arab Emirates   4.22215E+11   4.17216E+11   3.58869E+11   2.138094272
# Turkey                 7.78472E+11   7.61004E+11   7.19955E+11  -0.762423641
# Norway                    4.37E+11    4.0551E+11   3.62522E+11   -1.67804295
# Greece                 2.11946E+11   2.05144E+11   1.88835E+11  -4.523029108
# India                  2.70111E+12    2.8705E+12   2.66025E+12    4.62237855
# Singapore              3.75982E+11   3.74386E+11   3.39998E+11   3.490967515
# Vietnam                2.45214E+11   2.61921E+11   2.71158E+11   8.497016552
# China                  1.38948E+13   1.42799E+13   1.47227E+13   8.832103343
# Nigeria                 3.9719E+11    4.4812E+11   4.32294E+11   1.789633542
# South Africa           4.04842E+11   3.87935E+11   3.35442E+11  -2.185119558
# Egypt, Arab Rep.       2.49713E+11   3.03081E+11   3.65253E+11   5.115921666
# Australia              1.42853E+12   1.39195E+12   1.32784E+12   1.458872985
# Israel                 3.73641E+11   3.97935E+11   4.07101E+11   5.509460637

# %%
print("**************************")
print("2018 Human Capital Index")
print("**************************")

hci_df = trimmed_df.loc[trimmed_df['Series Name'] == 'Human capital index (HCI) (scale 0-1)']
hci_df = hci_df.drop(columns='Series Code')
hci_df = hci_df.drop(columns='Country Code')
hci_df = hci_df.drop(columns='Series Name')
hci_df = hci_df.drop(columns='2014 [YR2014]')
hci_df = hci_df.drop(columns='2015 [YR2015]')
hci_df = hci_df.drop(columns='2016 [YR2016]')
hci_df = hci_df.drop(columns='2017 [YR2017]')
hci_df = hci_df.drop(columns='2019 [YR2019]')
hci_df = hci_df.drop(columns='2020 [YR2020]')
hci_df = hci_df.drop(columns='2010-2020')
hci_df = hci_df.set_index('Country Name')
hci_df = hci_df.drop(index='Country List')
hci_df
# Out:
# **************************
# 2018 Human Capital Index
# **************************
#                      2018 [YR2018]
# Country Name
# Brazil                 0.545723736
# Argentina              0.617366731
# Colombia               0.598653853
# United States          0.713683248
# United Kingdom         0.776982248
# United Arab Emirates   0.676001251
# Turkey                 0.625309885
# Norway                 0.768534839
# Greece                 0.694805861
# India                  0.484795809
# Singapore               0.88708365
# Vietnam                0.687239349
# China                  0.647098839
# Nigeria                0.354753166
# South Africa           0.422549337
# Egypt, Arab Rep.       0.492512345
# Australia               0.78083396
# Israel                 0.763064444

# %%
# Isolate female labor force participation
labor_f_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.TLF.ACTI.1524.FE.ZS']
labor_f_df = labor_f_df.set_index('Country Name')
labor_f_df = labor_f_df.drop(columns='Series Code')
labor_f_df = labor_f_df.drop(columns='Country Code')
labor_f_df = labor_f_df.drop(columns='Series Name')
labor_f_df = labor_f_df.drop(columns='2020 [YR2020]')
labor_f_df = labor_f_df.drop(columns='2010-2020')
labor_f_df = labor_f_df.drop(index='Country List')

# Isolate male labor force participation
labor_m_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.TLF.ACTI.1524.MA.ZS']
labor_m_df = labor_m_df.set_index('Country Name')
labor_m_df = labor_m_df.drop(columns='Series Code')
labor_m_df = labor_m_df.drop(columns='Country Code')
labor_m_df = labor_m_df.drop(columns='Series Name')
labor_m_df = labor_m_df.drop(columns='2020 [YR2020]')
labor_m_df = labor_m_df.drop(columns='2010-2020')
labor_m_df = labor_m_df.drop(index='Country List')

# %%
print('Labor force participation rate for ages 15-24, female (%)')
labor_f_df
# Out:
# Labor force participation rate for ages 15-24, female (%)
#                      2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# Country Name
# Brazil                       47.04         47.13         48.16         49.41
# Argentina                    29.84         30.17         30.46         30.68
# Colombia                     45.45         45.63         45.24         44.76
# United States                49.79         50.11         50.45         51.18
# United Kingdom               55.73          56.7         56.99         56.34
# United Arab Emirates         30.64         30.88         30.63         32.23
# Turkey                       27.81          29.8         30.57         31.18
# Norway                       55.75         56.62         55.23         54.01
# Greece                       25.82         24.78         23.05         24.37
# India                        12.91          12.1         11.37          10.7
# Singapore                    38.83         41.17         39.01         38.44
# Vietnam                      56.29         56.81         55.24         55.13
# China                         47.7         46.27         45.06         44.06
# Nigeria                      22.76         24.46         26.28         27.79
# South Africa                 23.59         24.36         23.95         24.39
# Egypt, Arab Rep.             20.22         20.92         20.59         18.99
# Australia                    66.16         66.63         66.21         66.11
# Israel                       48.61         48.13         48.72         48.72
#
#                      2018 [YR2018] 2019 [YR2019]
# Country Name
# Brazil                       49.33         50.53
# Argentina                    31.83          31.5
# Colombia                     44.11         42.54
# United States                51.31         51.67
# United Kingdom               55.22         55.38
# United Arab Emirates         34.29         33.89
# Turkey                       31.33         32.63
# Norway                       54.63         55.84
# Greece                       22.47         22.09
# India                        10.09          9.82
# Singapore                    40.25         40.94
# Vietnam                      53.63          52.1
# China                        43.21          42.4
# Nigeria                      29.34         30.94
# South Africa                 22.71         23.14
# Egypt, Arab Rep.             11.88         11.86
# Australia                     67.2         67.58
# Israel                       48.15         47.51

# %%
print('Labor force participation rate for ages 15-24, male (%)')
labor_m_df
# Out:
# Labor force participation rate for ages 15-24, male (%)
#                      2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# Country Name
# Brazil                       62.59         62.26         61.66            62
# Argentina                    46.94          46.7         46.39         45.99
# Colombia                     64.34         64.49         62.58          61.3
# United States                52.39         52.44         52.94         53.22
# United Kingdom               59.11          59.7         58.87         57.92
# United Arab Emirates         65.67         65.16         63.56          63.7
# Turkey                       55.25         55.19         55.27         56.18
# Norway                        53.1         55.42          54.1         53.62
# Greece                       30.41         27.81         26.47         26.46
# India                        48.03         46.82         45.61         44.42
# Singapore                    40.86          42.4            42         43.01
# Vietnam                      63.24         64.25         62.16         62.39
# China                        52.95         51.56         50.42         49.55
# Nigeria                      28.43         30.88         33.57         34.38
# South Africa                 28.47         30.05         29.61         29.34
# Egypt, Arab Rep.             47.65         43.32         42.33         38.66
# Australia                     66.9         67.86         67.16         67.21
# Israel                       50.89         50.24         49.21          49.1
#
#                      2018 [YR2018] 2019 [YR2019]
# Country Name
# Brazil                       62.06         62.42
# Argentina                    45.84         45.18
# Colombia                     60.95         58.98
# United States                 52.4         53.06
# United Kingdom               58.15          57.3
# United Arab Emirates         64.15         64.61
# Turkey                        57.1          56.8
# Norway                       54.31         55.53
# Greece                       25.97         24.66
# India                        43.24         42.38
# Singapore                    42.87          43.7
# Vietnam                      60.83         59.58
# China                         48.9         48.31
# Nigeria                      35.34         36.42
# South Africa                 28.25         28.03
# Egypt, Arab Rep.             36.62         36.29
# Australia                    67.76         67.69
# Israel                       47.86         46.22

# %%
# Isolate employers data
employers_f_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.EMP.MPYR.FE.ZS']
employers_f_df = employers_f_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
employers_f_df = employers_f_df.rename(columns={"2018 [YR2018]": "Feamle - 2018"})
employers_f_df = employers_f_df.set_index("Country Name")
employers_f_df = employers_f_df.drop(index='Country List')




employers_m_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.EMP.MPYR.MA.ZS']
employers_m_df = employers_m_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
employers_m_df = employers_m_df.rename(columns={"2018 [YR2018]": "Male - 2018"})
employers_m_df = employers_m_df.set_index("Country Name")
employers_m_df = employers_m_df.drop(index='Country List')






employers_total_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.EMP.MPYR.ZS']
employers_total_df = employers_total_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
employers_total_df = employers_total_df.rename(columns={"2018 [YR2018]": "Total - 2018"})
employers_total_df = employers_total_df.set_index("Country Name")
employers_total_df = employers_total_df.drop(index='Country List')

# %%
employers_df = employers_f_df.merge(employers_m_df, on='Country Name')
employers_df = employers_df.merge(employers_total_df, on='Country Name')
employers_df
# Out:
#                      Feamle - 2018  Male - 2018 Total - 2018
# Country Name
# Brazil                 3.309999943            6  4.849999905
# Argentina              2.619999886  4.860000134  3.910000086
# Colombia               2.579999924   5.28000021  4.159999847
# United States          1.629999995  2.839999914  2.279999971
# United Kingdom          1.24000001  2.779999971  2.059999943
# United Arab Emirates   1.399999976  3.349999905  3.019999981
# Turkey                        1.25  5.960000038  4.460000038
# Norway                 0.819999993  2.210000038  1.559999943
# Greece                 4.739999771  9.619999886  7.619999886
# India                  0.519999981  2.390000105   2.00999999
# Singapore              2.569999933  5.639999866  4.360000134
# Vietnam                1.190000057   3.00999999  2.140000105
# China                  1.070000052  2.920000076  2.099999905
# Nigeria                0.159999996  0.409999996  0.300000012
# South Africa           2.289999962  7.570000172         5.25
# Egypt, Arab Rep.       3.809999943  14.57999992  12.35000038
# Australia              3.839999914   7.53000021  5.809999943
# Israel                 1.789999962  6.050000191   4.03000021

# %%
 

print("**************************")
print("Adolescent fertility rate (births per 1,000 women ages 15-19)")
print("**************************")

adolescent_mom_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SP.ADO.TFRT']
adolescent_mom_df = adolescent_mom_df.drop(columns='Series Code')
adolescent_mom_df = adolescent_mom_df.drop(columns='Country Code')
adolescent_mom_df = adolescent_mom_df.drop(columns='Series Name')
adolescent_mom_df = adolescent_mom_df.set_index('Country Name')
#adolescent_mom_df = adolescent_mom_df.drop(index='Country List')
adolescent_mom_df
# Out:
# **************************
# Adolescent fertility rate (births per 1,000 women ages 15-19)
# **************************
#                      2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# Country Name
# Brazil                     62.0762       61.0878       60.0994        59.111
# Argentina                   63.253        63.096        62.939        62.782
# Colombia                   70.6512       69.3178       67.9844        66.651
# United States              24.7062       23.0908       21.4754         19.86
# United Kingdom             16.4354       15.4136       14.3918         13.37
# United Arab Emirates       12.6804       10.6356        8.5908         6.546
# Turkey                     29.3694       28.4326       27.4958        26.559
# Norway                      5.6798        5.5002        5.3206         5.141
# Greece                      8.0126        7.7494        7.4862         7.223
# India                       22.102        19.127        16.152        13.177
# Singapore                   3.7574        3.6816        3.6058          3.53
# Vietnam                    34.0082       32.9818       31.9554        30.929
# China                       7.4802        7.5318        7.5834         7.635
# Nigeria                    113.162       111.218       109.274        107.33
# South Africa               70.3488       69.5352       68.7216        67.908
# Egypt, Arab Rep.            54.983        54.595        54.207        53.819
# Australia                  12.0672       11.9498       11.8324        11.715
# Israel                     10.7686       10.3814        9.9942         9.607
#
#                      2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2010-2020
# Country Name
# Brazil                     57.8858       56.6606            ..        ..
# Argentina                  62.5654       62.3488            ..        ..
# Colombia                    65.482        64.313            ..        ..
# United States              18.5562       17.2524            ..        ..
# United Kingdom              12.641        11.912            ..        ..
# United Arab Emirates        5.8868        5.2276            ..        ..
# Turkey                     25.5558       24.5526            ..        ..
# Norway                      5.1048        5.0686            ..        ..
# Greece                      6.9376        6.6522            ..        ..
# India                      12.0708       10.9646            ..        ..
# Singapore                   3.5134        3.4968            ..        ..
# Vietnam                    29.1518       27.3746            ..        ..
# China                        7.643         7.651            ..        ..
# Nigeria                    105.447       103.564            ..        ..
# South Africa               67.8488       67.7896            ..        ..
# Egypt, Arab Rep.            53.086        52.353            ..        ..
# Australia                  11.3258       10.9366            ..        ..
# Israel                       9.192         8.777            ..        ..

# %%
# Isolate population data
population_f_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SP.POP.TOTL.FE.IN']
population_f_df = population_f_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
population_f_df = population_f_df.rename(columns={"2018 [YR2018]": "Feamle - 2018"})
population_f_df = population_f_df.set_index("Country Name")
population_f_df = population_f_df.drop(index='Country List')




population_m_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SP.POP.TOTL.MA.IN']
population_m_df = population_m_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
population_m_df = population_m_df.rename(columns={"2018 [YR2018]": "Male - 2018"})
population_m_df = population_m_df.set_index("Country Name")
population_m_df = population_m_df.drop(index='Country List')






population_total_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SP.POP.TOTL']
population_total_df = population_total_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
population_total_df = population_total_df.rename(columns={"2018 [YR2018]": "Total - 2018"})
population_total_df = population_total_df.set_index("Country Name")
population_total_df = population_total_df.drop(index='Country List')

# %%
print("**************************")
print("2018 Population")
print("**************************")

population_df = population_f_df.merge(population_m_df, on='Country Name')
population_df = population_df.merge(population_total_df, on='Country Name')
population_df
# Out:
# **************************
# 2018 Population
# **************************
#                      Feamle - 2018 Male - 2018 Total - 2018
# Country Name
# Brazil                   106473081   102996239    209469320
# Argentina                 22797803    21696699     44494502
# Colombia                  25290276    24370780     49661056
# United States            165118706   161719493    326838199
# United Kingdom            33652378    32807966     66460344
# United Arab Emirates       2950609     6680357      9630966
# Turkey                    41728157    40611933     82340090
# Norway                     2630707     2681209      5311916
# Greece                     5464776     5268106     10732882
# India                    649586703   703055580   1352642283
# Singapore                  2687287     2951389      5638676
# Vietnam                   47865095    47680864     95545959
# China                    682854786   719905214   1402760000
# Nigeria                   96636957    99237728    195874685
# South Africa              29297427    28495093     57792520
# Egypt, Arab Rep.          48690128    49733474     98423602
# Australia                 12541215    12441473     24982688
# Israel                     4467882     4414918      8882800

# %%
##Unemployment, total (% of total labor force)

# Isolate unemployment data
unemployment_f_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.UEM.TOTL.FE.ZS']
unemployment_f_df = unemployment_f_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
unemployment_f_df = unemployment_f_df.rename(columns={"2018 [YR2018]": "Feamle - 2018"})
unemployment_f_df = unemployment_f_df.set_index("Country Name")
unemployment_f_df = unemployment_f_df.drop(index='Country List')




unemployment_m_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.UEM.TOTL.MA.ZS']
unemployment_m_df = unemployment_m_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
unemployment_m_df = unemployment_m_df.rename(columns={"2018 [YR2018]": "Male - 2018"})
unemployment_m_df = unemployment_m_df.set_index("Country Name")
unemployment_m_df = unemployment_m_df.drop(index='Country List')






unemployment_total_df = trimmed_df.loc[trimmed_df['Series Code'] == 'SL.UEM.TOTL.ZS']
unemployment_total_df = unemployment_total_df.drop(['Country Code',
                                      'Series Code',
                                      'Series Name',
                                      '2014 [YR2014]',
                                      '2015 [YR2015]',
                                      '2016 [YR2016]',
                                      '2017 [YR2017]',
                                      '2019 [YR2019]',
                                      '2020 [YR2020]',
                                      '2010-2020'],
                                     axis = 1)
unemployment_total_df = unemployment_total_df.rename(columns={"2018 [YR2018]": "Total - 2018"})
unemployment_total_df = unemployment_total_df.set_index("Country Name")
unemployment_total_df = unemployment_total_df.drop(index='Country List')

print("************************************")
print("2018 Unemployment (% of labor force)")
print("************************************")

unemployment_df = unemployment_f_df.merge(unemployment_m_df, on='Country Name')
unemployment_df = unemployment_df.merge(unemployment_total_df, on='Country Name')
unemployment_df
# Out:
# ************************************
# 2018 Unemployment (% of labor force)
# ************************************
#                      Feamle - 2018 Male - 2018 Total - 2018
# Country Name
# Brazil                       14.23       10.87        12.33
# Argentina                    10.54        8.23         9.22
# Colombia                     11.79        7.09         9.11
# United States                 3.84        3.95          3.9
# United Kingdom                3.94        4.05            4
# United Arab Emirates          6.19        1.39         2.23
# Turkey                       13.74        9.49        10.89
# Norway                        3.54        4.03          3.8
# Greece                       24.29       15.41        19.29
# India                          5.3        5.34         5.33
# Singapore                     3.79        3.55         3.65
# Vietnam                       1.03        1.28         1.16
# China                         3.72        4.75          4.3
# Nigeria                       8.36        8.51         8.45
# South Africa                 29.05       25.14        26.91
# Egypt, Arab Rep.             21.44        6.81         9.82
# Australia                     5.32        5.28          5.3
# Israel                        3.95        4.04            4
