# %%
import os
import csv
import pandas as pd

# %%
csvpath = os.path.join('raw_data', 'wdi_filtered_data.csv')

# %%
df = pd.read_csv(csvpath, encoding="ISO-8859-1")

# %%
df
# Out:
#                                        ï»¿Country Name Country Code  \
# 0                                               Brazil          BRA
# 1                                               Brazil          BRA
# 2                                               Brazil          BRA
# 3                                               Brazil          BRA
# 4                                               Brazil          BRA
# ...                                                ...          ...
# 5054                                               NaN          NaN
# 5055                                               NaN          NaN
# 5056                                               NaN          NaN
# 5057  Data from database: World Development Indicators          NaN
# 5058                          Last Updated: 12/16/2021          NaN
#
#                                             Series Name           Series Code  \
# ...

# %%
# Out:
#                                                      0  \
# 0       Adjusted net national income (annual % growth)
# 1     Adjusted net national income (constant 2015 US$)
# 2           Adjusted net national income (current US$)
# 3    Adjusted net national income per capita (annua...
# 4    Adjusted net national income per capita (const...
# ..                                                 ...
# 261  Women who believe a husband is justified in be...
# 262  Women who believe a husband is justified in be...
# 263  Women who were first married by age 15 (% of w...
# 264  Women who were first married by age 18 (% of w...
# 265  Women's share of population ages 15+ living wi...
#
#                                                      1
# 0               ï»¿Country Name    Country Code  \
# ...
# 1               ï»¿Country Name    Country Code  \
# ...
# 2               ï»¿Country Name    Country Code  \
# ...
# 3               ï»¿Country Name    Country Code  \
# ...
# ...
